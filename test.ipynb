# %%
from PIL import Image
import pytesseract
import numpy as np

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
# !pip install tesseract
# !pip install tesseract-ocr

# %%
filename = './Downloads/claim_sample.jpg'
img1 = np.array(Image.open(filename))
text = pytesseract.image_to_string(img1)

# %%
Image.open(filename)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1302x1677>

# %%
text
# Out:
# "Sample STERLING Option\n\n4500) CMS-1500 Form P.0.Box69314\nG\n: : Harrisburg, PA z\n|, =\n[4\nHEALTH INSURANCE CLAIM FORM 17106-9314 &\nAPPROVED BY NATIONAL UNIFORM CLAIM COMMITTEE 08/05 °\nMEDICARE MEDICAID TRICARE. CHAMPVA GROUP FECA OTHER) INSURED'S |.D. NUMBER (For Program in Item 1) is\nCHAMPUS, HEALTH PLAN -— BEKLUNG\n(Medicare #)[~ | (Medicaid #)[~ ] (Sponsor's SSN) (Member iD#) |__| (SSN'or 1D) (ssn) [X] a0 555-55-5555A\nPATIENT'S NAME (Last Name, First Name, Midale Inia) Dragenrggnmgge SEX INSURED'S NAME (Last Name, First Name, Middle inal)\n: i\nSmith, Bob A. 12:18:36 FLX] Same\n(@PATIENT'S ADDRESS (No, Street) PATIENT RELATIONSHIP TO INSURED (@ INSURED'S ADDRESS (No, Street)\n123 Paradise Road Sett[X] Spouse[_] chi] other Same\naay STATE (Q PATIENT StATUS civ STATE BS\nSeattle WA | singe FX] Maries other 2\nZIP CODE TELEPHONE (Include Area Code) ZIP CODE TELEPHONE (include Area Code) ES\nFull-Time — Part-Time} ©\n12345 (555) 555-1234 employed [_] Student L_] stuaent () 5\n© OTHER INSURED'S NAME (Last Name, Fst Namo, Midd inti) (QDIIS PATIENT'S CONDITION RELATED TO: INSURED'S POLICY GROUP OR FECA NUMBER, Fa\nNone 9\n@ otter INSURED'S POLICY OR GROUP NUMBER EMPLOYMENT? (Current or Previous) @ NSUREDS Date OF BIRTH SEX Fa\nMM) DD YY 5\nves [X]no \\ M F 2\nOores INSURED DATE OF BIRTH SEX AUTO ACCIDENT? PLACE (State) 40) EMPLOYER'S NAME OR SOHOOL NAME 9\nM F yes NO f <\n(QD EVPLOVER'S NAME OR SCHOOL NAME @orer accioenr? INSURANCE PLAN NAME OR PROGRAM NAME iE\nyes NO fs\n(@ INSURANCE PLAN NAME OR PROGRAM NAME ‘© RESERVED FOR LOCAL USE (Ds THERE ANOTHER HEALTH BENEFIT PLAN? <\nves NO Ifyes, return to and complete item 9 a\nREAD BACK OF FORM BEFORE COMPLETING & SIGNING THIS FORM, INSURED'S OR AUTHORIZED PERSON'S SIGNATURE | authorize\n1 parienr's on AUTHORIZED PERSON'S SIGNATURE: |anoie ne release o ony medal er ther infomation necessary | pasmentof medial bonetteo tre entorsonea pryloen os eonmlor tor\nto process this claim. | also request payment of government benefits either to myself orto the party who accepts assignment Services described below.\nbelow.\nsicneo__ Signature on File oare__ 08/14/2006 SIGNED iY\nDATE OF CURRENT: _g ILLNESS (First symptom) OR IF PATIENT HAS HAD SAME QR SIMILAR ILLNESS. RI) DATES PATIENT UNABLE,TO WORK IN CURRENT OCCUPATION\nMMT DO YY @ INJURY (Accident) OR GIVEFIASTDATE MM) OD')” YY Ba NDB MBE YY MMe DD) YY >\ni PREGNANCY(LMP) ! FROM To\n[QD wane OF REFERAING PROVIDER OR OTHER SOURCE [7a] Al WD HOSPITALIZATION DATES RELATED To CURRENT SERVICES\nLe |__| A J BBD OATES MMOD YY\nK. Brown, MD 170.|NP'| 1234567890 FROM | TO\nI aeseaveD Fon Local USE 1@) cursive tas? SGHARGES\nves [X]xo |\nJE) OIAGNOSIS OF NATURE OF ILLNESS OR INJURY (Relate ame 1,2, S014 fo Tem 24E by Une) 1@ wEDIGAD RESUBMISSION\nG6BE ORIGINAL REF. NO.\n1 [850,00 _ ot. _. |\n@ Prion AUTHORIZATION NUMBER\n2 .V58 61 4 . 50D0000000\n(DO __ dares oF seavICe O07 © Orcs saves orcs] O o  O7oe z\nFrom To lace oF (Explain Unusval Circumstances) DiaGNosis| obs BS] 9 RENDERING fa]\nMM__pD vy _wm_od___vy_|seavce| ema | cetmcecs | MODIFIER poten | _scuances | us _|'Sur | qua PROVIDER ID.# |e\n=\n1] 02 05;06) 02/05 06) 11 992128 i i a =\n| OS tt 55:00| 1 NPI\nead | 2 | e\n2} 02 05; 06) 02:05 06) 11 85610 i 1 ans ©\nited hited | | | | 1,2 30/00] 1 | | na =\na\n3] 02 08 | ; — Fe\n02 08) 06 | 02/05 06) 11 85635 PoE tthe 30/00| 1 w | 8322221111 |&\n3\n45 4 1 rod x\not tt NPI °\nH H S\na | Pott | cs 3\nL H i i NPI g\nFa\n— ' i eee\na l i - z\n[GD FEDERAL TAXID-NOWBER SSNEN [@PATENTSACCOUNTNO. JOD ACCEPTASSISNWENT? [QD TOTAL cHARGE AROUNT AD JEBAANCE DUE\n99-1234567 XI 12345987 EX]ves_ [_]no s 115 00} |s 115) 00)\nSIGNATURE OF PHYSICIAN OR SUPPLIER ‘SERVICE FACILITY LOCATION INFORMATION BILLING PROVIDER INFO & PH# a\nOrcimnceaeconccsamas | | Os aus (555) 555-5555\n(certify that the statements on the reverse Office Name Provider Name\napply to this bill and are made a part thereof.) 123 Main St. P.O. Box 12345\nT. Jones Seattle, WA 12348-2345 Sea ...
